# %%
import datetime
class Episode:
    def __init__(a,title,episode,season,game_time=None):
        a.title = title
        a.episode = episode
        a.season = season
        a.game_time = game_time

    def set_title(a,title):
        a.title = title

    def get_title(a):
        return a.title

    def set_episode(a,episode):
        a.episode = episode

    def get_episode(a):
        return a.episode

    def set_season(a,season):
        a.season = season

    def get_season(a):
        return a.season

    def set_game_time(a,game_time):
        a.game_time = game_time

    def get_game_time(a):
        return a.game_time


class TVserise:
    def __init__(a,title,description,release_data):
        a.title = title
        a.description = description
        a.release_data = release_data
        a.episode = []


    def set_title(a,title):
        a.title = title

    def get_title(a):
        return a.title
 
    def set_description(a,desc):
        a.description = desc

    def get_description(a):
        return a.description

    def set_release_data(a,relea):
        a.release_data = relea

    def get_release(a):
        return a.release_data

    def add_episode(a,e):
        a.episode.append(e)

    def set_episode(a,episode):
        a.episode = episode
        
    def get_episode(a):
        return a.episode

if __name__=="__main__":
    release_data = datetime.date(2002,8,25)
    descrip = "he lives of six reckless adults living in Manhattan, as they indulge in adventures which make their lives both troublesome and happening"
    madrase = TVserise ("madrase",descrip,release_data)

    eq1=Episode("engio of this fellam",40,10,60)

    madrase.add_episode(eq1)

    for i in madrase.get_episode():
        print("Title  ",i.title)
        print("Epiosde no   ",i.episode)
        print("season  ",i.season)
        print("game_time  ",i.game_time)
# Out:
# Title   engio of this fellam
# Epiosde no    40
# season   10
# game_time   60

# %%
import datetime
class Episode:
    def __init__(a,title,episode_num,season_num,game_time=None):
        a.title = title
        a.episode_num = episode_num
        a.season_num = season_num
        a.game_time = game_time

    def __str__(a):
        return f"title:{a.title},episode_num:{a.episode_num},season_num:{a.season_num},game_time:{a.game_time}"

class TVserise:
    def __init__(a,title,description,release_date) :
        a.title = title
        a.description = description
        a.release_date = release_date
        a.episode = []

    def __str__(a):
        return f"title:{a.title},description:{a.description},release_date:{a.release_date},episode:{a.episode}"
        
    
    def add_episode(a,e):
        a.episode.append(e)

    def get_episode(a):
        return a.episode

if __name__=="__main__":
    release = datetime.date(2001,8,19)
    hello = TVserise("faine","to kabi kabi mala kar",release)
    hi0 = Episode("K G F",12,7,60)
    hi1 =Episode("The One Where It All Begin",1,1,45 )
    hi2 =Episode("The One ",2,1,45 )
    hi3 =Episode("Where It All Begin",3,1,45 )
    hi4 =Episode("Begin",4,1,45 )
    hello.add_episode(hi0)
    hello.add_episode(hi1)
    hello.add_episode(hi2)
    hello.add_episode(hi3)
    hello.add_episode(hi4)
    # print(hello)

    for i in hello.episode:
        print(i)
