# %%
class Car:
    def __init__(a,deshbord,seat,bettery,engin):
        a.deshbord = deshbord
        a.seat = seat
        a.bettery = bettery
        a.engin = engin

    def __str__(a):
        return f"deshbord mad in {a.deshbord}:seat by in {a.seat}:bettery is in campany{a.bettery}:engin is brand by {a.engin}"

class Engin:
    def __init__(a,company,horse_power,fule):
        a.company = company
        a.horse_power = horse_power
        a.fule = fule

    def __str__(a):
        return f"company name is {a.company}:horse power in speed{a.horse_power}:fule is {a.fule}"

class Basecar(Car):
    def __init__(a, deshbord, seat, bettery, engin,speaker):
        super().__init__(deshbord, seat, bettery, engin)
        a.speaker = speaker

    def __str__(a):
        return f"BASE CAR:speaker is {a.speaker} {super().__str__()}"
    

class Sportcar(Car):
    def __init__(a, deshbord, seat, bettery, engin,tire):
        super().__init__(deshbord, seat, bettery, engin)
        a.tire =tire

    def __str__(a):
        return f"SPORT CAR :tire is {a.tire} {super().__str__()}"

class Luxurycar(Car):
    def __init__(a, deshbord, seat, bettery, engin,new_model):
        super().__init__(deshbord, seat, bettery, engin)
        a.new_model =new_model

    def __str__(a):
        return f"LUXURY CAR:new model is luanch {a.new_model} {super().__str__()}"

class Electricengin(Engin):
    def __init__(a, company, horse_power, fule,bettery):
        super().__init__(company, horse_power, fule)
        a.bettery = bettery

    def __str__(a):
        return f"ELECTRIC ENGIN:is bettery{a.bettery} {super().__str__()}"

class Peterolengin(Engin):
    def __init__(a, company, horse_power, fule,bettery):
        super().__init__(company, horse_power, fule)
        a.bettery = bettery

    def __str__(a):
        return f"PETEROL ENGIN:is bettery{a.bettery} {super().__str__()}"

class Hybridengin(Engin):
    def __init__(a, company, horse_power, fule,bettery):
        super().__init__(company, horse_power, fule) 
        a.bettery = bettery

    def __str__(a):
        return f"HYBARID ENGIN:is bettery{a.bettery} {super().__str__()}"


C1 = Engin("toyota",2000,"yes")
C2 = Car("lether","fome","oska",C1)
print(C1)
print(C2)

m1 = Basecar("lather","fomr","AGS","suzuki","normall")
print(m1)


m2=Sportcar("plastic","fome","AGS","audi","sport_tire")
print(m2)


m3 = Luxurycar("matel","fome","jan-bettery","KGF","2023")
print(m3)

m4=Peterolengin("jan",3000,"peterol","oska",)
print(m4)


m5 =Electricengin("lamborigne",2000,"Electric","mama")
print(m5)

m6 = Hybridengin("abubakar",5000,"electric","abu")
print(m6)
