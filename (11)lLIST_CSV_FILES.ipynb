# %%
import csv

with open('favorites.csv') as f:
    reader = csv.DictReader(f)
    for rows in reader:
        c = 0
        print(rows['genres'],['Comedy'])
# Out:
# Comedy ['Comedy']
# Comedy, Crime, Drama, Horror, Sci-Fi, Talk-Show, Thriller ['Comedy']
# Drama, Family, Sport ['Comedy']
# Animation, Comedy ['Comedy']
# Comedy ['Comedy']
# Comedy ['Comedy']
# Comedy ['Comedy']
# Crime, Drama ['Comedy']
# Comedy ['Comedy']
# Comedy ['Comedy']
# Action, Crime, Drama ['Comedy']
# Comedy, Family ['Comedy']
# Action, Adventure, Drama, Fantasy, Thriller, War ['Comedy']
# Action, Drama, Fantasy, History, Romance ['Comedy']
# Action, Sci-Fi ['Comedy']
# Comedy, Family ['Comedy']
# Comedy ['Comedy']
# Comedy ['Comedy']
# Comedy ['Comedy']
# Adventure, Animation ['Comedy']
# Action, Sport ['Comedy']
# Crime, Drama, Mystery ['Comedy']
# Comedy ['Comedy']
# Action, Crime, Fantasy ['Comedy']
# Comedy, Romance ['Comedy']
# Game-Show ['Comedy']
# Crime, Mystery ['Comedy']
# Action, Comedy, Crime ['Comedy']
# Action, Adventure, Animation, Comedy, Family, Fantasy ['Comedy']
# Comedy ['Comedy']
# Action, Animation, Comedy ['Comedy']
# Comedy ['Comedy']
# ...
